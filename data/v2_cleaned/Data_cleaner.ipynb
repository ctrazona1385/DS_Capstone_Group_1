# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
cdc = pd.read_csv('cdc_prevalence.csv')
#cdc[cdc.isna().any(axis=1)].to_csv('stinky_nan_havers.csv')
#Kentucky and Maryland are missing nearly all data... but we know they don't go to the denist.
cdc.dropna(inplace=True)
cdc.to_csv('cdc_cleaned.csv')

# %%
census = pd.read_csv('census_county_data.csv')
census.to_csv('census_cleaned.csv')

# %%
sahie = pd.read_csv('/sahie_county_data.csv')
sahie.isna().sum() #only one NaN row with all NaN (to be dropped)
sahie.dropna(inplace=True)
sahie.to_csv('sahie_cleaned.csv')
